# %%
import pandas as pd

# %%
# read the csv file into a pandas dataframe
df_tuitionAdd = pd.read_csv('tuition and additional compulsory fees.csv')
df_tuitionAdd
# Out:
#       REF_DATE     GEO           DGUID          Level of study  \
# 0    2019/2020  Canada  2016A000011124  Canadian undergraduate
# 1    2020/2021  Canada  2016A000011124  Canadian undergraduate
# 2    2021/2022  Canada  2016A000011124  Canadian undergraduate
# 3    2022/2023  Canada  2016A000011124  Canadian undergraduate
# 4    2023/2024  Canada  2016A000011124  Canadian undergraduate
# ..         ...     ...             ...                     ...
# 115  2019/2020   Yukon     2016A000260       Canadian graduate
# 116  2020/2021   Yukon     2016A000260       Canadian graduate
# 117  2021/2022   Yukon     2016A000260       Canadian graduate
# 118  2022/2023   Yukon     2016A000260       Canadian graduate
# 119  2023/2024   Yukon     2016A000260       Canadian graduate
#
#                  UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR  \
# 0    Current dollars      75         units          0   v107791652
# 1    Current dollars      75         units          0   v107791652
# ...

# %%
# getting information about dataset
df_tuitionAdd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REF_DATE        120 non-null    object
#  1   GEO             120 non-null    object
#  2   DGUID           120 non-null    object
#  3   Level of study  120 non-null    object
#  4   UOM             120 non-null    object
#  5   UOM_ID          120 non-null    int64
#  6   SCALAR_FACTOR   120 non-null    object
#  7   SCALAR_ID       120 non-null    int64
#  8   VECTOR          120 non-null    object
#  9   COORDINATE      120 non-null    float64
#  10  VALUE           115 non-null    float64
#  11  STATUS          5 non-null      object
#  12  SYMBOL          0 non-null      float64
#  13  TERMINATED      0 non-null      float64
#  14  DECIMALS        120 non-null    int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 14.2+ KB

# %%
# For better understanding information in the dataset to print the unique values and their counts for the column
# loop through each column in the dataframe
for column in df_tuitionAdd.columns:
    print(df_tuitionAdd[column].value_counts())
# Out:
# 2019/2020    24
# 2020/2021    24
# 2021/2022    24
# 2022/2023    24
# 2023/2024    24
# Name: REF_DATE, dtype: int64
# Canada                       10
# Newfoundland and Labrador    10
# Prince Edward Island         10
# Nova Scotia                  10
# New Brunswick                10
# Quebec                       10
# Ontario                      10
# Manitoba                     10
# Saskatchewan                 10
# Alberta                      10
# British Columbia             10
# Yukon                        10
# Name: GEO, dtype: int64
# 2016A000011124    10
# 2016A000210       10
# 2016A000211       10
# 2016A000212       10
# 2016A000213       10
# 2016A000224       10
# 2016A000235       10
# 2016A000246       10
# 2016A000247       10
# 2016A000248       10
# 2016A000259       10
# 2016A000260       10
# Name: DGUID, dtype: int64
# Canadian undergraduate    60
# Canadian graduate         60
# Name: Level of study, dtype: int64
# Current dollars    120
# ...

# %%
# drop unrelated/blank columns
df_tuitionAdd.drop(['DGUID','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'], axis=1, inplace=True)
df_tuitionAdd
# Out:
#       REF_DATE     GEO          Level of study   VALUE
# 0    2019/2020  Canada  Canadian undergraduate  7382.0
# 1    2020/2021  Canada  Canadian undergraduate  7508.0
# 2    2021/2022  Canada  Canadian undergraduate  7659.0
# 3    2022/2023  Canada  Canadian undergraduate  7916.0
# 4    2023/2024  Canada  Canadian undergraduate  8167.0
# ..         ...     ...                     ...     ...
# 115  2019/2020   Yukon       Canadian graduate     NaN
# 116  2020/2021   Yukon       Canadian graduate     NaN
# 117  2021/2022   Yukon       Canadian graduate     NaN
# 118  2022/2023   Yukon       Canadian graduate     NaN
# 119  2023/2024   Yukon       Canadian graduate     NaN
#
# [120 rows x 4 columns]

# %%
# drop null values
df_tuitionAdd.dropna(inplace=True)
df_tuitionAdd
# Out:
#       REF_DATE     GEO          Level of study   VALUE
# 0    2019/2020  Canada  Canadian undergraduate  7382.0
# 1    2020/2021  Canada  Canadian undergraduate  7508.0
# 2    2021/2022  Canada  Canadian undergraduate  7659.0
# 3    2022/2023  Canada  Canadian undergraduate  7916.0
# 4    2023/2024  Canada  Canadian undergraduate  8167.0
# ..         ...     ...                     ...     ...
# 110  2019/2020   Yukon  Canadian undergraduate  4210.0
# 111  2020/2021   Yukon  Canadian undergraduate  4312.0
# 112  2021/2022   Yukon  Canadian undergraduate  4387.0
# 113  2022/2023   Yukon  Canadian undergraduate  4590.0
# 114  2023/2024   Yukon  Canadian undergraduate  4669.0
#
# [115 rows x 4 columns]

# %%
# save the dataframe as csv file
df_tuitionAdd.to_csv('cleaned_tuition_additional_compulsory_fees.csv', index=False)

# %%
# read the csv file into a pandas dataframe
df_tuitionUgr = pd.read_csv('undergraduate tuition fees by field of study.csv')
df_tuitionUgr
# Out:
#        REF_DATE     GEO           DGUID  \
# 0     2019/2020  Canada  2016A000011124
# 1     2020/2021  Canada  2016A000011124
# 2     2021/2022  Canada  2016A000011124
# 3     2022/2023  Canada  2016A000011124
# 4     2023/2024  Canada  2016A000011124
# ...         ...     ...             ...
# 1195  2019/2020   Yukon     2016A000260
# 1196  2020/2021   Yukon     2016A000260
# 1197  2021/2022   Yukon     2016A000260
# 1198  2022/2023   Yukon     2016A000260
# 1199  2023/2024   Yukon     2016A000260
#
#                                         Field of study              UOM  \
# 0                                Total, field of study  Current dollars
# 1                                Total, field of study  Current dollars
# 2                                Total, field of study  Current dollars
# 3                                Total, field of study  Current dollars
# 4                                Total, field of study  Current dollars
# ...

# %%
# getting information about dataset
df_tuitionUgr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REF_DATE        1200 non-null   object
#  1   GEO             1200 non-null   object
#  2   DGUID           1200 non-null   object
#  3   Field of study  1200 non-null   object
#  4   UOM             1200 non-null   object
#  5   UOM_ID          1200 non-null   int64
#  6   SCALAR_FACTOR   1200 non-null   object
#  7   SCALAR_ID       1200 non-null   int64
#  8   VECTOR          1200 non-null   object
#  9   COORDINATE      1200 non-null   float64
#  10  VALUE           977 non-null    float64
#  11  STATUS          223 non-null    object
#  12  SYMBOL          0 non-null      float64
#  13  TERMINATED      0 non-null      float64
#  14  DECIMALS        1200 non-null   int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 140.8+ KB

# %%
# For better understanding information in the dataset to print the unique values and their counts for the column
# loop through each column in the dataframe
for column in df_tuitionUgr.columns:
    print(df_tuitionUgr[column].value_counts())
# Out:
# 2019/2020    240
# 2020/2021    240
# 2021/2022    240
# 2022/2023    240
# 2023/2024    240
# Name: REF_DATE, dtype: int64
# Canada                       100
# Newfoundland and Labrador    100
# Prince Edward Island         100
# Nova Scotia                  100
# New Brunswick                100
# Quebec                       100
# Ontario                      100
# Manitoba                     100
# Saskatchewan                 100
# Alberta                      100
# British Columbia             100
# Yukon                        100
# Name: GEO, dtype: int64
# 2016A000011124    100
# 2016A000210       100
# 2016A000211       100
# 2016A000212       100
# 2016A000213       100
# 2016A000224       100
# 2016A000235       100
# 2016A000246       100
# 2016A000247       100
# 2016A000248       100
# 2016A000259       100
# 2016A000260       100
# Name: DGUID, dtype: int64
# Total, field of study                                          60
# ...

# %%
# drop unrelated/blank columns
df_tuitionUgr.drop(['DGUID','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'], axis=1, inplace=True)
df_tuitionUgr
# Out:
#        REF_DATE     GEO                                    Field of study  \
# 0     2019/2020  Canada                             Total, field of study
# 1     2020/2021  Canada                             Total, field of study
# 2     2021/2022  Canada                             Total, field of study
# 3     2022/2023  Canada                             Total, field of study
# 4     2023/2024  Canada                             Total, field of study
# ...         ...     ...                                               ...
# 1195  2019/2020   Yukon  Personal, protective and transportation services
# 1196  2020/2021   Yukon  Personal, protective and transportation services
# 1197  2021/2022   Yukon  Personal, protective and transportation services
# 1198  2022/2023   Yukon  Personal, protective and transportation services
# 1199  2023/2024   Yukon  Personal, protective and transportation services
#
#        VALUE
# 0     6468.0
# 1     6580.0
# 2     6660.0
# 3     6872.0
# ...

# %%
# drop null values
df_tuitionUgr.dropna(inplace=True)
df_tuitionUgr
# Out:
#        REF_DATE     GEO                                  Field of study  \
# 0     2019/2020  Canada                           Total, field of study
# 1     2020/2021  Canada                           Total, field of study
# 2     2021/2022  Canada                           Total, field of study
# 3     2022/2023  Canada                           Total, field of study
# 4     2023/2024  Canada                           Total, field of study
# ...         ...     ...                                             ...
# 1130  2019/2020   Yukon  Business, management and public administration
# 1131  2020/2021   Yukon  Business, management and public administration
# 1132  2021/2022   Yukon  Business, management and public administration
# 1133  2022/2023   Yukon  Business, management and public administration
# 1134  2023/2024   Yukon  Business, management and public administration
#
#        VALUE
# 0     6468.0
# 1     6580.0
# 2     6660.0
# 3     6872.0
# 4     7076.0
# ...      ...
# ...

# %%
# save the dataframe as csv file
df_tuitionUgr.to_csv('cleaned_undergraduate_tuition_fees.csv', index=False)

# %%
# read the csv file into a pandas dataframe
df_tuitionGr = pd.read_csv('graduate tuition fees by field of study.csv')
df_tuitionGr
# Out:
#        REF_DATE     GEO           DGUID  \
# 0     2019/2020  Canada  2016A000011124
# 1     2020/2021  Canada  2016A000011124
# 2     2021/2022  Canada  2016A000011124
# 3     2022/2023  Canada  2016A000011124
# 4     2023/2024  Canada  2016A000011124
# ...         ...     ...             ...
# 1293  2022/2023   Yukon     2016A000260
# 1294  2019/2020   Yukon     2016A000260
# 1295  2020/2021   Yukon     2016A000260
# 1296  2021/2022   Yukon     2016A000260
# 1297  2022/2023   Yukon     2016A000260
#
#                                         Field of study              UOM  \
# 0                                Total, field of study  Current dollars
# 1                                Total, field of study  Current dollars
# 2                                Total, field of study  Current dollars
# 3                                Total, field of study  Current dollars
# 4                                Total, field of study  Current dollars
# ...

# %%
# getting information about dataset
df_tuitionGr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1298 entries, 0 to 1297
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REF_DATE        1298 non-null   object
#  1   GEO             1298 non-null   object
#  2   DGUID           1298 non-null   object
#  3   Field of study  1298 non-null   object
#  4   UOM             1298 non-null   object
#  5   UOM_ID          1298 non-null   int64
#  6   SCALAR_FACTOR   1298 non-null   object
#  7   SCALAR_ID       1298 non-null   int64
#  8   VECTOR          1298 non-null   object
#  9   COORDINATE      1298 non-null   float64
#  10  VALUE           943 non-null    float64
#  11  STATUS          355 non-null    object
#  12  SYMBOL          0 non-null      float64
#  13  TERMINATED      0 non-null      float64
#  14  DECIMALS        1298 non-null   int64
# dtypes: float64(4), int64(3), object(8)
# memory usage: 152.2+ KB

# %%
# For better understanding information in the dataset to print the unique values and their counts for the column
# loop through each column in the dataframe
for column in df_tuitionGr.columns:
    print(df_tuitionGr[column].value_counts())
# Out:
# 2019/2020    264
# 2020/2021    264
# 2021/2022    264
# 2022/2023    264
# 2023/2024    242
# Name: REF_DATE, dtype: int64
# Canada                       110
# Newfoundland and Labrador    110
# Prince Edward Island         110
# Nova Scotia                  110
# New Brunswick                110
# Quebec                       110
# Ontario                      110
# Manitoba                     110
# Saskatchewan                 110
# Alberta                      110
# British Columbia             110
# Yukon                         88
# Name: GEO, dtype: int64
# 2016A000011124    110
# 2016A000210       110
# 2016A000211       110
# 2016A000212       110
# 2016A000213       110
# 2016A000224       110
# 2016A000235       110
# 2016A000246       110
# 2016A000247       110
# 2016A000248       110
# 2016A000259       110
# 2016A000260        88
# Name: DGUID, dtype: int64
# Total, field of study                                          59
# ...

# %%
# drop unrelated/blank columns
df_tuitionGr.drop(['DGUID','UOM','UOM_ID','SCALAR_FACTOR','SCALAR_ID','VECTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'], axis=1, inplace=True)
df_tuitionGr
# Out:
#        REF_DATE     GEO                                    Field of study  \
# 0     2019/2020  Canada                             Total, field of study
# 1     2020/2021  Canada                             Total, field of study
# 2     2021/2022  Canada                             Total, field of study
# 3     2022/2023  Canada                             Total, field of study
# 4     2023/2024  Canada                             Total, field of study
# ...         ...     ...                                               ...
# 1293  2022/2023   Yukon       Other health, parks, recreation and fitness
# 1294  2019/2020   Yukon  Personal, protective and transportation services
# 1295  2020/2021   Yukon  Personal, protective and transportation services
# 1296  2021/2022   Yukon  Personal, protective and transportation services
# 1297  2022/2023   Yukon  Personal, protective and transportation services
#
#        VALUE
# 0     7186.0
# 1     7361.0
# 2     7315.0
# 3     7409.0
# ...

# %%
# drop null values
df_tuitionGr.dropna(inplace=True)
df_tuitionGr
# Out:
#        REF_DATE               GEO  \
# 0     2019/2020            Canada
# 1     2020/2021            Canada
# 2     2021/2022            Canada
# 3     2022/2023            Canada
# 4     2023/2024            Canada
# ...         ...               ...
# 1205  2019/2020  British Columbia
# 1206  2020/2021  British Columbia
# 1207  2021/2022  British Columbia
# 1208  2022/2023  British Columbia
# 1209  2023/2024  British Columbia
#
#                                         Field of study    VALUE
# 0                                Total, field of study   7186.0
# 1                                Total, field of study   7361.0
# 2                                Total, field of study   7315.0
# 3                                Total, field of study   7409.0
# 4                                Total, field of study   7573.0
# ...                                                ...      ...
# 1205  Personal, protective and transportation services  12640.0
# ...

# %%
# save the dataframe as csv file
df_tuitionGr.to_csv('cleaned_graduate_tuition_fees.csv', index=False)

# %%
# read the csv file into a pandas dataframe
df_labourSt = pd.read_csv('labour force status.csv')
df_labourSt
# Out:
#       REF_DATE      GEO           DGUID Statistics (3)      Gender (3)  \
# 0         2021   Canada  2021A000011124          Count  Total - Gender
# 1         2021   Canada  2021A000011124          Count  Total - Gender
# 2         2021   Canada  2021A000011124          Count  Total - Gender
# 3         2021   Canada  2021A000011124          Count  Total - Gender
# 4         2021   Canada  2021A000011124          Count  Total - Gender
# ...        ...      ...             ...            ...             ...
# 1779      2021  Nunavut     2021A000262          Count  Total - Gender
# 1780      2021  Nunavut     2021A000262          Count  Total - Gender
# 1781      2021  Nunavut     2021A000262          Count  Total - Gender
# 1782      2021  Nunavut     2021A000262          Count  Total - Gender
# 1783      2021  Nunavut     2021A000262          Count  Total - Gender
#
#         Age (15A)     Highest certificate, diploma or degree (16)  \
# ...

# %%
# getting information about dataset
df_labourSt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1784 entries, 0 to 1783
# Data columns (total 19 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   REF_DATE                                     1784 non-null   int64
#  1   GEO                                          1784 non-null   object
#  2   DGUID                                        1784 non-null   object
#  3   Statistics (3)                               1784 non-null   object
#  4   Gender (3)                                   1784 non-null   object
#  5   Age (15A)                                    1784 non-null   object
#  6   Highest certificate, diploma or degree (16)  1784 non-null   object
#  7   Labour force status (8)                      1784 non-null   object
#  8   UOM                                          0 non-null      float64
# ...

# %%
# For better understanding information in the dataset to print the unique values and their counts for the column
# loop through each column in the dataframe
for column in df_labourSt.columns:
    print(df_labourSt[column].value_counts())
# Out:
# 2021    1784
# Name: REF_DATE, dtype: int64
# Canada                       128
# Newfoundland and Labrador    128
# Prince Edward Island         128
# Nova Scotia                  128
# New Brunswick                128
# Quebec                       128
# Ontario                      128
# Manitoba                     128
# Saskatchewan                 128
# Alberta                      128
# British Columbia             128
# Yukon                        127
# Northwest Territories        126
# Nunavut                      123
# Name: GEO, dtype: int64
# 2021A000011124    128
# 2021A000210       128
# 2021A000211       128
# 2021A000212       128
# 2021A000213       128
# 2021A000224       128
# 2021A000235       128
# 2021A000246       128
# 2021A000247       128
# 2021A000248       128
# 2021A000259       128
# 2021A000260       127
# 2021A000261       126
# 2021A000262       123
# Name: DGUID, dtype: int64
# Count    1784
# Name: Statistics (3), dtype: int64
# ...

# %%
# drop unrelated/blank columns
df_labourSt.drop(['DGUID','Statistics (3)','Gender (3)','Age (15A)','UOM','UOM_ID','SCALAR_ID','VECTOR','SCALAR_FACTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'], axis=1, inplace=True)
df_labourSt
# Out:
#       REF_DATE      GEO     Highest certificate, diploma or degree (16)  \
# 0         2021   Canada  Total - Highest certificate, diploma or degree
# 1         2021   Canada  Total - Highest certificate, diploma or degree
# 2         2021   Canada  Total - Highest certificate, diploma or degree
# 3         2021   Canada  Total - Highest certificate, diploma or degree
# 4         2021   Canada  Total - Highest certificate, diploma or degree
# ...        ...      ...                                             ...
# 1779      2021  Nunavut                                Earned doctorate
# 1780      2021  Nunavut                                Earned doctorate
# 1781      2021  Nunavut                                Earned doctorate
# 1782      2021  Nunavut                                Earned doctorate
# 1783      2021  Nunavut                                Earned doctorate
#
#           Labour force status (8)       VALUE
# 0     Total - Labour force status  30335915.0
# ...

# %%
# save the dataframe as csv file
df_labourSt.to_csv('cleaned_labour_force_status.csv', index=False)

# %%
# read the csv file into a pandas dataframe
df_medianIncome = pd.read_csv('median employment income two, five and ten years.csv')
df_medianIncome
# Out:
#       REF_DATE               GEO           DGUID  \
# 0         2011            Canada  2021A000011124
# 1         2011            Canada  2021A000011124
# 2         2011            Canada  2021A000011124
# 3         2011            Canada  2021A000011124
# 4         2011            Canada  2021A000011124
# ...        ...               ...             ...
# 1537      2011  British Columbia     2021A000259
# 1538      2011  British Columbia     2021A000259
# 1539      2011  British Columbia     2021A000259
# 1540      2011  British Columbia     2021A000259
# 1541      2011  British Columbia     2021A000259
#
#                               Educational qualification  \
# 0     Career, technical or professional training dip...
# 1     Career, technical or professional training dip...
# 2     Career, technical or professional training dip...
# 3     Career, technical or professional training dip...
# 4     Career, technical or professional training dip...
# ...

# %%
# getting information about dataset
df_medianIncome.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1542 entries, 0 to 1541
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   REF_DATE                          1542 non-null   int64
#  1   GEO                               1542 non-null   object
#  2   DGUID                             1542 non-null   object
#  3   Educational qualification         1542 non-null   object
#  4   Field of study                    1542 non-null   object
#  5   Gender                            1542 non-null   object
#  6   Age group                         1542 non-null   object
#  7   Status of student in Canada       1542 non-null   object
#  8   Characteristics after graduation  1542 non-null   object
#  9   Graduate statistics               1542 non-null   object
#  10  UOM                               1542 non-null   object
# ...

# %%
# For better understanding information in the dataset to print the unique values and their counts for the column
# loop through each column in the dataframe
for column in df_medianIncome.columns:
    print(df_medianIncome[column].value_counts())
# Out:
# 2011    1542
# Name: REF_DATE, dtype: int64
# Canada                       162
# Alberta                      162
# British Columbia             159
# Quebec                       156
# Manitoba                     147
# Saskatchewan                 147
# Nova Scotia                  138
# Newfoundland and Labrador    132
# New Brunswick                132
# Ontario                      123
# Prince Edward Island          84
# Name: GEO, dtype: int64
# 2021A000011124    162
# 2021A000248       162
# 2021A000259       159
# 2021A000224       156
# 2021A000246       147
# 2021A000247       147
# 2021A000212       138
# 2021A000210       132
# 2021A000213       132
# 2021A000235       123
# 2021A000211        84
# Name: DGUID, dtype: int64
# Undergraduate degree                                  411
# Master's degree                                       384
# Career, technical or professional training diploma    330
# Doctoral degree                                       327
# ...

# %%
# drop unrelated/blank columns
df_medianIncome.drop(['DGUID','Gender','Age group','Status of student in Canada','Characteristics after graduation','UOM','UOM_ID','SCALAR_ID','VECTOR','SCALAR_FACTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'], axis=1, inplace=True)
df_medianIncome
# Out:
#       REF_DATE               GEO  \
# 0         2011            Canada
# 1         2011            Canada
# 2         2011            Canada
# 3         2011            Canada
# 4         2011            Canada
# ...        ...               ...
# 1537      2011  British Columbia
# 1538      2011  British Columbia
# 1539      2011  British Columbia
# 1540      2011  British Columbia
# 1541      2011  British Columbia
#
#                               Educational qualification  \
# 0     Career, technical or professional training dip...
# 1     Career, technical or professional training dip...
# 2     Career, technical or professional training dip...
# 3     Career, technical or professional training dip...
# 4     Career, technical or professional training dip...
# ...                                                 ...
# 1537                                    Doctoral degree
# 1538                                    Doctoral degree
# ...

# %%
# drop null values
df_medianIncome.dropna(inplace=True)
df_medianIncome
# Out:
#       REF_DATE               GEO  \
# 0         2011            Canada
# 1         2011            Canada
# 2         2011            Canada
# 3         2011            Canada
# 4         2011            Canada
# ...        ...               ...
# 1531      2011  British Columbia
# 1532      2011  British Columbia
# 1533      2011  British Columbia
# 1534      2011  British Columbia
# 1535      2011  British Columbia
#
#                               Educational qualification  \
# 0     Career, technical or professional training dip...
# 1     Career, technical or professional training dip...
# 2     Career, technical or professional training dip...
# 3     Career, technical or professional training dip...
# 4     Career, technical or professional training dip...
# ...                                                 ...
# 1531                                    Doctoral degree
# 1532                                    Doctoral degree
# ...

# %%
# save the dataframe as csv file
df_medianIncome.to_csv('cleaned_median_employment_income_years.csv', index=False)

# %%
# read the csv file into a pandas dataframe
df_statIncome = pd.read_csv('employment income statistics.csv')
df_statIncome
# Out:
#       REF_DATE      GEO           DGUID      Gender (3)     Age (22)  \
# 0         2021   Canada  2021A000011124  Total - Gender  Total - Age
# 1         2021   Canada  2021A000011124  Total - Gender  Total - Age
# 2         2021   Canada  2021A000011124  Total - Gender  Total - Age
# 3         2021   Canada  2021A000011124  Total - Gender  Total - Age
# 4         2021   Canada  2021A000011124  Total - Gender  Total - Age
# ...        ...      ...             ...             ...          ...
# 3559      2021  Nunavut     2021A000262  Total - Gender  Total - Age
# 3560      2021  Nunavut     2021A000262  Total - Gender  Total - Age
# 3561      2021  Nunavut     2021A000262  Total - Gender  Total - Age
# 3562      2021  Nunavut     2021A000262  Total - Gender  Total - Age
# 3563      2021  Nunavut     2021A000262  Total - Gender  Total - Age
#
#          Highest certificate, diploma or degree (16)  \
# 0     Total - Highest certificate, diploma or degree
# ...

# %%
# getting information about dataset
df_statIncome.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3564 entries, 0 to 3563
# Data columns (total 21 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   REF_DATE                                                                         3564 non-null   int64
#  1   GEO                                                                              3564 non-null   object
#  2   DGUID                                                                            3564 non-null   object
#  3   Gender (3)                                                                       3564 non-null   object
#  4   Age (22)                                                                         3564 non-null   object
#  5   Highest certificate, diploma or degree (16)                                      3564 non-null   object
# ...

# %%
# For better understanding information in the dataset to print the unique values and their counts for the column
# loop through each column in the dataframe
for column in df_statIncome.columns:
    print(df_statIncome[column].value_counts())
# Out:
# 2021    3564
# Name: REF_DATE, dtype: int64
# Canada                       255
# Newfoundland and Labrador    255
# Nova Scotia                  255
# New Brunswick                255
# Quebec                       255
# Ontario                      255
# Manitoba                     255
# Saskatchewan                 255
# Alberta                      255
# British Columbia             255
# Northwest Territories        255
# Prince Edward Island         253
# Yukon                        253
# Nunavut                      253
# Name: GEO, dtype: int64
# 2021A000011124    255
# 2021A000210       255
# 2021A000212       255
# 2021A000213       255
# 2021A000224       255
# 2021A000235       255
# 2021A000246       255
# 2021A000247       255
# 2021A000248       255
# 2021A000259       255
# 2021A000261       255
# 2021A000211       253
# 2021A000260       253
# 2021A000262       253
# Name: DGUID, dtype: int64
# Total - Gender    3564
# Name: Gender (3), dtype: int64
# ...

# %%
# drop unrelated/blank columns
df_statIncome.drop(['DGUID','Gender (3)','Age (22)','Work activity during the reference year (5)','Income year (2)','UOM','UOM_ID','SCALAR_ID','VECTOR','SCALAR_FACTOR','COORDINATE','STATUS','SYMBOL','TERMINATED','DECIMALS'], axis=1, inplace=True)
df_statIncome
# Out:
#       REF_DATE      GEO     Highest certificate, diploma or degree (16)  \
# 0         2021   Canada  Total - Highest certificate, diploma or degree
# 1         2021   Canada  Total - Highest certificate, diploma or degree
# 2         2021   Canada  Total - Highest certificate, diploma or degree
# 3         2021   Canada  Total - Highest certificate, diploma or degree
# 4         2021   Canada  Total - Highest certificate, diploma or degree
# ...        ...      ...                                             ...
# 3559      2021  Nunavut    Postsecondary certificate, diploma or degree
# 3560      2021  Nunavut    Postsecondary certificate, diploma or degree
# 3561      2021  Nunavut    Postsecondary certificate, diploma or degree
# 3562      2021  Nunavut    Postsecondary certificate, diploma or degree
# 3563      2021  Nunavut    Postsecondary certificate, diploma or degree
#
#      Major field of study - Classification of Instructional Programs (CIP) 2021 (14)  \
# ...

# %%
# save the dataframe as csv file
df_statIncome.to_csv('cleaned_employment_income_statistics.csv', index=False)
