# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
# read the csv file into a pandas dataframe
incomeYR_df = pd.read_csv("Cleaned_GraduatesReportingEmploymentIncome.csv")
incomeYR_df.head()
# Out:
#    REF_DATE     GEO                          Educational qualification  \
# 0      2011  Canada  Career, technical or professional training cer...
# 1      2011  Canada  Career, technical or professional training cer...
# 2      2011  Canada  Career, technical or professional training cer...
# 3      2011  Canada  Career, technical or professional training cer...
# 4      2011  Canada  Career, technical or professional training cer...
#
#           Field of study                                Graduate statistics  \
# 0  Total, field of study                                Number of graduates
# 1  Total, field of study  Median employment income two years after gradu...
# 2  Total, field of study  Median employment income five years after grad...
# 3  Total, field of study  Median employment income ten years after gradu...
# 4          Education [1]                                Number of graduates
#
#                      UOM    VALUE STATUS
# ...

# %%
#getting information about dataset
incomeYR_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2428 entries, 0 to 2427
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   REF_DATE                   2428 non-null   int64
#  1   GEO                        2428 non-null   object
#  2   Educational qualification  2428 non-null   object
#  3   Field of study             2428 non-null   object
#  4   Graduate statistics        2428 non-null   object
#  5   UOM                        2428 non-null   object
#  6   VALUE                      2008 non-null   float64
#  7   STATUS                     420 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 151.9+ KB

# %%
# getting basic statistics about dataset
incomeYR_df.describe()
# Out:
#        REF_DATE          VALUE
# count    2428.0    2008.000000
# mean     2011.0   46356.404382
# std         0.0   36377.913869
# min      2011.0       0.000000
# 25%      2011.0     907.500000
# 50%      2011.0   47700.000000
# 75%      2011.0   75600.000000
# max      2011.0  142000.000000

# %%
# loop through each column in the dataframe
for column in incomeYR_df.columns:
    # print the unique values and their counts for the current column
    print(incomeYR_df[column].value_counts())
# Out:
# 2011    2428
# Name: REF_DATE, dtype: int64
# Canada                       268
# Alberta                      264
# British Columbia             260
# Manitoba                     240
# Saskatchewan                 236
# Nova Scotia                  220
# Quebec                       216
# New Brunswick                212
# Newfoundland and Labrador    204
# Ontario                      164
# Prince Edward Island         144
# Name: GEO, dtype: int64
# Undergraduate degree                                      548
# Master's degree                                           512
# Career, technical or professional training diploma        440
# Doctoral degree                                           436
# Career, technical or professional training certificate    372
# Professional degree                                       120
# Name: Educational qualification, dtype: int64
# Total, field of study                                              252
# ...

# %%
incomeEd_df = pd.read_csv("Cleaned_IncomeHighestEducationMajorField.csv")
incomeEd_df.head()
# Out:
#    REF_DATE     GEO     Highest certificate, diploma or degree (16)  \
# 0      2021  Canada  Total - Highest certificate, diploma or degree
# 1      2021  Canada  Total - Highest certificate, diploma or degree
# 2      2021  Canada  Total - Highest certificate, diploma or degree
# 3      2021  Canada  Total - Highest certificate, diploma or degree
# 4      2021  Canada  Total - Highest certificate, diploma or degree
#
#   Major field of study - Classification of Instructional Programs (CIP) 2021 (14)  \
# 0  Total - Major field of study - Classification ...
# 1  Total - Major field of study - Classification ...
# 2  Total - Major field of study - Classification ...
# 3  Total - Major field of study - Classification ...
# 4  Total - Major field of study - Classification ...
#
#        Employment income statistics (7)     VALUE STATUS
# 0  Total - Employment income statistics  30335920    NaN
# 1                With employment income  21127690    NaN
# ...

# %%
incomeEd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 923 entries, 0 to 922
# Data columns (total 7 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   REF_DATE                                                                         923 non-null    int64
#  1   GEO                                                                              923 non-null    object
#  2   Highest certificate, diploma or degree (16)                                      923 non-null    object
#  3   Major field of study - Classification of Instructional Programs (CIP) 2021 (14)  923 non-null    object
#  4   Employment income statistics (7)                                                 923 non-null    object
#  5   VALUE                                                                            923 non-null    int64
# ...

# %%
for column in incomeEd_df.columns:
    print(incomeEd_df[column].value_counts())
# Out:
# 2021    923
# Name: REF_DATE, dtype: int64
# Canada    923
# Name: GEO, dtype: int64
# Total - Highest certificate, diploma or degree                     98
# Postsecondary certificate, diploma or degree                       95
# Postsecondary certificate or diploma below bachelor level          95
# College, CEGEP or other non-university certificate or diploma      95
# University certificate or diploma below bachelor level             95
# Bachelor’s degree or higher                                        95
# Bachelor's degree                                                  95
# University certificate or diploma above bachelor level             95
# Master's degree                                                    95
# Degree in medicine, dentistry, veterinary medicine or optometry    65
# Name: Highest certificate, diploma or degree (16), dtype: int64
# Total - Major field of study - Classification of Instructional Programs (CIP) 2021    70
# ...

# %%
labourstatus_df = pd.read_csv("Cleaned_LabourForce.csv")
labourstatus_df.head(20)
# Out:
#     REF_DATE     GEO        Highest certificate, diploma or degree (16)  \
# 0       2021  Canada     Total - Highest certificate, diploma or degree
# 1       2021  Canada     Total - Highest certificate, diploma or degree
# 2       2021  Canada     Total - Highest certificate, diploma or degree
# 3       2021  Canada     Total - Highest certificate, diploma or degree
# 4       2021  Canada     Total - Highest certificate, diploma or degree
# 5       2021  Canada     Total - Highest certificate, diploma or degree
# 6       2021  Canada     Total - Highest certificate, diploma or degree
# 7       2021  Canada     Total - Highest certificate, diploma or degree
# 8       2021  Canada                  No certificate, diploma or degree
# 9       2021  Canada                  No certificate, diploma or degree
# 10      2021  Canada                  No certificate, diploma or degree
# 11      2021  Canada                  No certificate, diploma or degree
# ...

# %%
labourstatus_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1784 entries, 0 to 1783
# Data columns (total 5 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   REF_DATE                                     1784 non-null   int64
#  1   GEO                                          1784 non-null   object
#  2   Highest certificate, diploma or degree (16)  1784 non-null   object
#  3   Labour force status (8)                      1784 non-null   object
#  4   VALUE                                        1784 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 69.8+ KB

# %%
for column in labourstatus_df.columns:
    print(labourstatus_df[column].value_counts())
# Out:
# 2021    1784
# Name: REF_DATE, dtype: int64
# Canada                       128
# Newfoundland and Labrador    128
# Prince Edward Island         128
# Nova Scotia                  128
# New Brunswick                128
# Quebec                       128
# Ontario                      128
# Manitoba                     128
# Saskatchewan                 128
# Alberta                      128
# British Columbia             128
# Yukon                        127
# Northwest Territories        126
# Nunavut                      123
# Name: GEO, dtype: int64
# Total - Highest certificate, diploma or degree                     112
# No certificate, diploma or degree                                  112
# High (secondary) school diploma or equivalency certificate         112
# Postsecondary certificate, diploma or degree                       112
# Postsecondary certificate or diploma below bachelor level          112
# Apprenticeship or trades certificate or diploma                    112
# ...

# %%
tuition_df = pd.read_csv("Cleaned_UndergraduateTuitionFees.csv")
tuition_df.head(20)
# Out:
#      REF_DATE     GEO                                     Field of study  \
# 0   2022/2023  Canada                              Total, field of study
# 1   2023/2024  Canada                              Total, field of study
# 2   2022/2023  Canada                                          Education
# 3   2023/2024  Canada                                          Education
# 4   2022/2023  Canada  Visual and performing arts, and communications...
# 5   2023/2024  Canada  Visual and performing arts, and communications...
# 6   2022/2023  Canada                                         Humanities
# 7   2023/2024  Canada                                         Humanities
# 8   2022/2023  Canada  Social and behavioural sciences, and legal stu...
# 9   2023/2024  Canada  Social and behavioural sciences, and legal stu...
# 10  2022/2023  Canada                                                Law
# 11  2023/2024  Canada                                                Law
# ...

# %%
tuition_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REF_DATE        398 non-null    object
#  1   GEO             398 non-null    object
#  2   Field of study  398 non-null    object
#  3   VALUE           392 non-null    float64
#  4   STATUS          6 non-null      object
# dtypes: float64(1), object(4)
# memory usage: 15.7+ KB

# %%
for column in tuition_df.columns:
    print(tuition_df[column].value_counts())
# Out:
# 2022/2023    199
# 2023/2024    199
# Name: REF_DATE, dtype: int64
# Canada                       40
# Quebec                       40
# Ontario                      40
# Saskatchewan                 38
# Alberta                      38
# Nova Scotia                  36
# Manitoba                     36
# British Columbia             36
# Newfoundland and Labrador    30
# New Brunswick                30
# Prince Edward Island         26
# Yukon                         8
# Name: GEO, dtype: int64
# Total, field of study                                          24
# Business management and public administration                  24
# Physical and life sciences and technologies                    24
# Education                                                      24
# Nursing                                                        22
# Visual and performing arts, and communications technologies    22
# Humanities                                                     22
# ...

# %%
tuitionAdd_df = pd.read_csv("Cleaned_TuitionAdditionalFees.csv")
tuitionAdd_df.head(20)
# Out:
#      REF_DATE                        GEO          Level of study   VALUE
# 0   2019/2020                     Canada  Canadian undergraduate  7382.0
# 1   2020/2021                     Canada  Canadian undergraduate  7508.0
# 2   2021/2022                     Canada  Canadian undergraduate  7659.0
# 3   2022/2023                     Canada  Canadian undergraduate  7916.0
# 4   2023/2024                     Canada  Canadian undergraduate  8167.0
# 5   2019/2020                     Canada       Canadian graduate  8048.0
# 6   2020/2021                     Canada       Canadian graduate  8245.0
# 7   2021/2022                     Canada       Canadian graduate  8282.0
# 8   2022/2023                     Canada       Canadian graduate  8400.0
# 9   2023/2024                     Canada       Canadian graduate  8608.0
# 10  2019/2020  Newfoundland and Labrador  Canadian undergraduate  3821.0
# 11  2020/2021  Newfoundland and Labrador  Canadian undergraduate  3806.0
# ...

# %%
tuitionAdd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   REF_DATE        120 non-null    object
#  1   GEO             120 non-null    object
#  2   Level of study  120 non-null    object
#  3   VALUE           115 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 3.9+ KB

# %%
for column in tuitionAdd_df.columns:
    print(tuitionAdd_df[column].value_counts())
# Out:
# 2019/2020    24
# 2020/2021    24
# 2021/2022    24
# 2022/2023    24
# 2023/2024    24
# Name: REF_DATE, dtype: int64
# Canada                       10
# Newfoundland and Labrador    10
# Prince Edward Island         10
# Nova Scotia                  10
# New Brunswick                10
# Quebec                       10
# Ontario                      10
# Manitoba                     10
# Saskatchewan                 10
# Alberta                      10
# British Columbia             10
# Yukon                        10
# Name: GEO, dtype: int64
# Canadian undergraduate    60
# Canadian graduate         60
# Name: Level of study, dtype: int64
# 7382.0     1
# 4620.0     1
# 9794.0     1
# 9390.0     1
# 8968.0     1
#           ..
# 10653.0    1
# 10312.0    1
# 10048.0    1
# 9556.0     1
# 4669.0     1
# Name: VALUE, Length: 115, dtype: int64
